# %%
import polars as pl
import pathlib
import numpy as np

path_to_data = pathlib.Path("data/titanic.csv")

# %%
df = pl.read_csv(path_to_data)
df.head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬─────────────────┬─────┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name            ┆ ... ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---             ┆     ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str             ┆     ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═════════════════╪═════╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr.     ┆ ... ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Owen Harris     ┆     ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.   ┆ ... ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley    ┆     ┆           ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Flor...        ┆     ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen,      ┆ ... ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Miss. Laina     ┆     ┆ 3101282   ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴─────────────────┴─────┴───────────┴─────────┴───────┴──────────┘

# %%
df[0]
# Out:
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬────────────────────┬─────┬───────────┬──────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name               ┆ ... ┆ Ticket    ┆ Fare ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                ┆     ┆ ---       ┆ ---  ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str                ┆     ┆ str       ┆ f64  ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪════════════════════╪═════╪═══════════╪══════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen   ┆ ... ┆ A/5 21171 ┆ 7.25 ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris             ┆     ┆           ┆      ┆       ┆          │
# └─────────────┴──────────┴────────┴────────────────────┴─────┴───────────┴──────┴───────┴──────────┘

# %%
df[[2, 3]]
# Out:
# shape: (2, 12)
# ┌─────────────┬──────────┬────────┬────────────────────┬─────┬──────────┬───────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name               ┆ ... ┆ Ticket   ┆ Fare  ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                ┆     ┆ ---      ┆ ---   ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str                ┆     ┆ str      ┆ f64   ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪════════════════════╪═════╪══════════╪═══════╪═══════╪══════════╡
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.   ┆ ... ┆ STON/O2. ┆ 7.925 ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina              ┆     ┆ 3101282  ┆       ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.     ┆ ... ┆ 113803   ┆ 53.1  ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath      ┆     ┆          ┆       ┆       ┆          │
# │             ┆          ┆        ┆ (Li...             ┆     ┆          ┆       ┆       ┆          │
# └─────────────┴──────────┴────────┴────────────────────┴─────┴──────────┴───────┴───────┴──────────┘

# %%
df[:2]
# Out:
# shape: (2, 12)
# ┌─────────────┬──────────┬────────┬─────────────────┬─────┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name            ┆ ... ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---             ┆     ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str             ┆     ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═════════════════╪═════╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr.     ┆ ... ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Owen Harris     ┆     ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.   ┆ ... ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley    ┆     ┆           ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Flor...        ┆     ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴─────────────────┴─────┴───────────┴─────────┴───────┴──────────┘

# %%
df[range(2, 4)]
# Out:
# shape: (2, 12)
# ┌─────────────┬──────────┬────────┬────────────────────┬─────┬──────────┬───────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name               ┆ ... ┆ Ticket   ┆ Fare  ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                ┆     ┆ ---      ┆ ---   ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str                ┆     ┆ str      ┆ f64   ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪════════════════════╪═════╪══════════╪═══════╪═══════╪══════════╡
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.   ┆ ... ┆ STON/O2. ┆ 7.925 ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina              ┆     ┆ 3101282  ┆       ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.     ┆ ... ┆ 113803   ┆ 53.1  ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath      ┆     ┆          ┆       ┆       ┆          │
# │             ┆          ┆        ┆ (Li...             ┆     ┆          ┆       ┆       ┆          │
# └─────────────┴──────────┴────────┴────────────────────┴─────┴──────────┴───────┴───────┴──────────┘

# %%
df[np.arange(0, 3)]
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬─────────────────┬─────┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name            ┆ ... ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---             ┆     ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str             ┆     ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═════════════════╪═════╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr.     ┆ ... ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Owen Harris     ┆     ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.   ┆ ... ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley    ┆     ┆           ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Flor...        ┆     ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen,      ┆ ... ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Miss. Laina     ┆     ┆ 3101282   ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴─────────────────┴─────┴───────────┴─────────┴───────┴──────────┘

# %%
# NOTE - you can't pass boolean masks to Polars Eager Dfs
df[[True for _ in range(len(df))]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # NOTE - you can't pass boolean masks to Polars Eager Dfs
# ----> 2 df[[True for _ in range(len(df))]]
#
# File ~/opt/anaconda3/envs/udemy_polars_env/lib/python3.11/site-packages/polars/internals/dataframe/frame.py:1382, in DataFrame.__getitem__(self, item)
#    1377         return self._from_pydf(
#    1378             self._df.take_with_series(self._pos_idxs(item, dim=0)._s)
#    1379         )
#    1381 # if no data has been returned, the operation is not supported
# -> 1382 raise ValueError(
#    1383     f"Cannot __getitem__ on DataFrame with item: '{item}'"
#    1384     f" of type: '{type(item)}'."
#    1385 )
#
# ValueError: Cannot __getitem__ on DataFrame with item: 'shape: (891,)
# Series: '' [bool]
# [
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	...
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# 	true
# ]' of type: '<class 'polars.internals.series.series.Series'>'.

# %%
# so this very familiar adage from pandas doesn't work
df[df["Age"] > 30]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # so this very familiar adage from pandas doesn't work
# ----> 2 df[df["Age"] > 30]
#
# File ~/opt/anaconda3/envs/udemy_polars_env/lib/python3.11/site-packages/polars/internals/dataframe/frame.py:1382, in DataFrame.__getitem__(self, item)
#    1377         return self._from_pydf(
#    1378             self._df.take_with_series(self._pos_idxs(item, dim=0)._s)
#    1379         )
#    1381 # if no data has been returned, the operation is not supported
# -> 1382 raise ValueError(
#    1383     f"Cannot __getitem__ on DataFrame with item: '{item}'"
#    1384     f" of type: '{type(item)}'."
#    1385 )
#
# ValueError: Cannot __getitem__ on DataFrame with item: 'shape: (891,)
# Series: 'Age' [bool]
# [
# 	false
# 	true
# 	false
# 	true
# 	true
# 	null
# 	true
# 	false
# 	false
# 	false
# 	false
# 	true
# 	...
# 	null
# 	true
# 	false
# 	true
# 	false
# 	false
# 	false
# 	true
# 	false
# 	false
# 	null
# 	false
# 	true
# ]' of type: '<class 'polars.internals.series.series.Series'>'.

# %% [markdown]
# # Filtering in Eager Mode
# The primary way to filter rows in Polars is too use the `filter` method with the Expression API. The main use case of the bracket accessor is to select rows when quickly inspecting data in interactive mode.

# %%
df.filter(
    pl.col('Pclass') == 1
).head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬─────┬──────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ ... ┆ Ticket   ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆     ┆ ---      ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆     ┆ str      ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═════╪══════════╪═════════╪═══════╪══════════╡
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.    ┆ ... ┆ PC 17599 ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley     ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Flor...         ┆     ┆          ┆         ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.   ┆ ... ┆ 113803   ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath    ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Li...           ┆     ┆          ┆         ┆       ┆          │
# │ 7           ┆ 0        ┆ 1      ┆ McCarthy, Mr.    ┆ ... ┆ 17463    ┆ 51.8625 ┆ E46   ┆ S        │
# │             ┆          ┆        ┆ Timothy J        ┆     ┆          ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴──────────────────┴─────┴──────────┴─────────┴───────┴──────────┘

# %% [markdown]
# `[]` indexing can **only** be used in eager mode, whereas `filter` can be used in both. Also, `filter` expressions are optimized by the query optimizer in lazy mode.

# %%
# you can add an explicit row number column using:
df_with_row_number = df.with_row_count(name="row_nr")
df_with_row_number.head(3)
# Out:
# shape: (3, 13)
# ┌────────┬─────────────┬──────────┬────────┬─────┬──────────────────┬─────────┬───────┬──────────┐
# │ row_nr ┆ PassengerId ┆ Survived ┆ Pclass ┆ ... ┆ Ticket           ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---    ┆ ---         ┆ ---      ┆ ---    ┆     ┆ ---              ┆ ---     ┆ ---   ┆ ---      │
# │ u32    ┆ i64         ┆ i64      ┆ i64    ┆     ┆ str              ┆ f64     ┆ str   ┆ str      │
# ╞════════╪═════════════╪══════════╪════════╪═════╪══════════════════╪═════════╪═══════╪══════════╡
# │ 0      ┆ 1           ┆ 0        ┆ 3      ┆ ... ┆ A/5 21171        ┆ 7.25    ┆ null  ┆ S        │
# │ 1      ┆ 2           ┆ 1        ┆ 1      ┆ ... ┆ PC 17599         ┆ 71.2833 ┆ C85   ┆ C        │
# │ 2      ┆ 3           ┆ 1        ┆ 3      ┆ ... ┆ STON/O2. 3101282 ┆ 7.925   ┆ null  ┆ S        │
# └────────┴─────────────┴──────────┴────────┴─────┴──────────────────┴─────────┴───────┴──────────┘

# %%
# then you can use that row number to do index based indexing in lazy mode, with the filter expression
df_with_row_number.filter(
    pl.col('row_nr') < 4
)
# Out:
# shape: (4, 13)
# ┌────────┬─────────────┬──────────┬────────┬─────┬──────────────────┬─────────┬───────┬──────────┐
# │ row_nr ┆ PassengerId ┆ Survived ┆ Pclass ┆ ... ┆ Ticket           ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---    ┆ ---         ┆ ---      ┆ ---    ┆     ┆ ---              ┆ ---     ┆ ---   ┆ ---      │
# │ u32    ┆ i64         ┆ i64      ┆ i64    ┆     ┆ str              ┆ f64     ┆ str   ┆ str      │
# ╞════════╪═════════════╪══════════╪════════╪═════╪══════════════════╪═════════╪═══════╪══════════╡
# │ 0      ┆ 1           ┆ 0        ┆ 3      ┆ ... ┆ A/5 21171        ┆ 7.25    ┆ null  ┆ S        │
# │ 1      ┆ 2           ┆ 1        ┆ 1      ┆ ... ┆ PC 17599         ┆ 71.2833 ┆ C85   ┆ C        │
# │ 2      ┆ 3           ┆ 1        ┆ 3      ┆ ... ┆ STON/O2. 3101282 ┆ 7.925   ┆ null  ┆ S        │
# │ 3      ┆ 4           ┆ 1        ┆ 1      ┆ ... ┆ 113803           ┆ 53.1    ┆ C123  ┆ S        │
# └────────┴─────────────┴──────────┴────────┴─────┴──────────────────┴─────────┴───────┴──────────┘

# %% [markdown]
# In eager mode, chaining calls of `.filter` will actually still generate multiple dataframes for each step.
# To get the benefits of Polars, make sure that you chain the conditions of the `.filter()` calls with the `&` operator.
# This will lead to the evaluation of the `.filter` operation over a single pass through the data.

# %%
# naive - using multiple conditions
df_naive_multiple_conditions = (
    df
    .filter(
        pl.col('Pclass') == 1
    )
    .filter(
        (pl.col('Age') > 70)
    )
)
df_naive_multiple_conditions.head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬─────┬──────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ ... ┆ Ticket   ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆     ┆ ---      ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆     ┆ str      ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═════╪══════════╪═════════╪═══════╪══════════╡
# │ 97          ┆ 0        ┆ 1      ┆ Goldschmidt, Mr. ┆ ... ┆ PC 17754 ┆ 34.6542 ┆ A5    ┆ C        │
# │             ┆          ┆        ┆ George B         ┆     ┆          ┆         ┆       ┆          │
# │ 494         ┆ 0        ┆ 1      ┆ Artagaveytia,    ┆ ... ┆ PC 17609 ┆ 49.5042 ┆ null  ┆ C        │
# │             ┆          ┆        ┆ Mr. Ramon        ┆     ┆          ┆         ┆       ┆          │
# │ 631         ┆ 1        ┆ 1      ┆ Barkworth, Mr.   ┆ ... ┆ 27042    ┆ 30.0    ┆ A23   ┆ S        │
# │             ┆          ┆        ┆ Algernon Henry   ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ Wi...            ┆     ┆          ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴──────────────────┴─────┴──────────┴─────────┴───────┴──────────┘

# %%
# better way - using multiple conditions
df_better_multiple_conditions = (
    df
    .filter(
        (pl.col('Pclass') == 1) & (pl.col('Age') > 70)
    )
)
df_better_multiple_conditions.head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬─────┬──────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ ... ┆ Ticket   ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆     ┆ ---      ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆     ┆ str      ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═════╪══════════╪═════════╪═══════╪══════════╡
# │ 97          ┆ 0        ┆ 1      ┆ Goldschmidt, Mr. ┆ ... ┆ PC 17754 ┆ 34.6542 ┆ A5    ┆ C        │
# │             ┆          ┆        ┆ George B         ┆     ┆          ┆         ┆       ┆          │
# │ 494         ┆ 0        ┆ 1      ┆ Artagaveytia,    ┆ ... ┆ PC 17609 ┆ 49.5042 ┆ null  ┆ C        │
# │             ┆          ┆        ┆ Mr. Ramon        ┆     ┆          ┆         ┆       ┆          │
# │ 631         ┆ 1        ┆ 1      ┆ Barkworth, Mr.   ┆ ... ┆ 27042    ┆ 30.0    ┆ A23   ┆ S        │
# │             ┆          ┆        ┆ Algernon Henry   ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ Wi...            ┆     ┆          ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴──────────────────┴─────┴──────────┴─────────┴───────┴──────────┘

# %%
# better way - using multiple conditions
df_or_better_multiple_conditions = (
    df
    .filter(
        (pl.col('Pclass') == 1) | (pl.col('Age') > 70)
    )
)
df_or_better_multiple_conditions.head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬─────┬──────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ ... ┆ Ticket   ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆     ┆ ---      ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆     ┆ str      ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═════╪══════════╪═════════╪═══════╪══════════╡
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.    ┆ ... ┆ PC 17599 ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley     ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Flor...         ┆     ┆          ┆         ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.   ┆ ... ┆ 113803   ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath    ┆     ┆          ┆         ┆       ┆          │
# │             ┆          ┆        ┆ (Li...           ┆     ┆          ┆         ┆       ┆          │
# │ 7           ┆ 0        ┆ 1      ┆ McCarthy, Mr.    ┆ ... ┆ 17463    ┆ 51.8625 ┆ E46   ┆ S        │
# │             ┆          ┆        ┆ Timothy J        ┆     ┆          ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴──────────────────┴─────┴──────────┴─────────┴───────┴──────────┘

# %% [markdown]
# # Filtering in Lazy Mode

# %%
df_lazy = pl.scan_csv(path_to_data)
df_lazy
# Out:
# <i>naive plan: (run <b>LazyFrame.describe_optimized_plan()</b> to see the optimized plan)</i>
#     <p></p>
#     <div>  CSV SCAN data/titanic.csv<p></p>  PROJECT */12 COLUMNS<p></p></div>

# %%
df_with_lazy_filter = df_lazy.filter(pl.col("Age") > 30)
df_with_lazy_filter
# Out:
# <i>naive plan: (run <b>LazyFrame.describe_optimized_plan()</b> to see the optimized plan)</i>
#     <p></p>
#     <div>  FILTER [(col("Age")) > (30i32)] FROM<p></p>    CSV SCAN data/titanic.csv<p></p>    PROJECT */12 COLUMNS<p></p></div>

# %%
print(df_with_lazy_filter.describe_optimized_plan())
# Out:
#   CSV SCAN data/titanic.csv
#   PROJECT */12 COLUMNS
#   SELECTION: [(col("Age")) > (30f64)]

# %% [markdown]
# Here is how you show predicate pushdown at work - combining multiple filter statements into a single pass over the data.

# %%
df_with_multiple_lazy_filters = (
    df_lazy
    .filter(
        pl.col("Pclass") == 1
    )
    .filter(
        pl.col("Age") > 70
    )
)
df_with_multiple_lazy_filters.describe_optimized_plan()
# Out:
# '  CSV SCAN data/titanic.csv\n  PROJECT */12 COLUMNS\n  SELECTION: [([(col("Age")) > (70f64)]) & ([(col("Pclass")) == (1i64)])]\n'
